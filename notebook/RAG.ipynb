# %%
! uv pip install langchain openai tiktoken rapidocr-onnxruntime python-dotenv langchain-community langchain-classic langchain-groq
# Out:
# Using Python 3.12.1 environment at: C:\Users\Kethavath\multi-doc-chat\.venv
# Resolved 74 packages in 1.30s
# Downloading pydantic-core (1.9MiB)
# Downloading sqlalchemy (2.0MiB)
# Downloading shapely (1.6MiB)
# Downloading pillow (6.7MiB)
# Downloading opencv-python (38.3MiB)
# Downloading openai (1.1MiB)
# Downloading langchain-community (2.4MiB)
# Downloading numpy (11.7MiB)
# Downloading sympy (6.0MiB)
# Downloading onnxruntime (11.9MiB)
# Downloading rapidocr-onnxruntime (14.2MiB)
#  Downloaded shapely
#  Downloaded pydantic-core
#  Downloaded sqlalchemy
#  Downloaded pillow
#  Downloaded openai
#  Downloaded langchain-community
#  Downloaded numpy
#  Downloaded rapidocr-onnxruntime
#  Downloaded sympy
#  Downloaded onnxruntime
#  Downloaded opencv-python
# Prepared 70 packages in 37.48s
# Installed 70 packages in 1.27s
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.3
#  + aiosignal==1.4.0
#  + annotated-types==0.7.0
#  + anyio==4.12.1
#  + attrs==25.4.0
#  + certifi==2026.1.4
#  + charset-normalizer==3.4.4
#  + dataclasses-json==0.6.7
#  + distro==1.9.0
#  + flatbuffers==25.12.19
#  + frozenlist==1.8.0
#  + greenlet==3.3.1
#  + groq==0.37.1
#  + h11==0.16.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + httpx-sse==0.4.3
#  + idna==3.11
#  + jiter==0.13.0
#  + jsonpatch==1.33
#  + jsonpointer==3.0.0
#  + langchain==1.2.10
#  + langchain-classic==1.0.1
#  + langchain-community==0.4.1
#  + langchain-core==1.2.13
#  + langchain-groq==1.1.2
#  + langchain-text-splitters==1.1.0
#  + langgraph==1.0.8
#  + langgraph-checkpoint==4.0.0
#  + langgraph-prebuilt==1.0.7
#  + langgraph-sdk==0.3.6
#  + langsmith==0.7.3
#  + marshmallow==3.26.2
#  + mpmath==1.3.0
#  + multidict==6.7.1
#  + mypy-extensions==1.1.0
#  + numpy==2.4.2
#  + onnxruntime==1.24.1
#  + openai==2.21.0
#  + opencv-python==4.13.0.92
#  + orjson==3.11.7
#  + ormsgpack==1.12.2
#  + pillow==12.1.1
#  + propcache==0.4.1
#  + protobuf==6.33.5
#  + pyclipper==1.4.0
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + pydantic-settings==2.13.0
#  + pyyaml==6.0.3
#  + rapidocr-onnxruntime==1.4.4
#  + regex==2026.1.15
#  + requests==2.32.5
#  + requests-toolbelt==1.0.0
#  + shapely==2.1.2
#  + sniffio==1.3.1
#  + sqlalchemy==2.0.46
#  + sympy==1.14.0
#  + tenacity==9.1.4
#  + tiktoken==0.12.0
#  + tqdm==4.67.3
#  + typing-extensions==4.15.0
#  + typing-inspect==0.9.0
#  + typing-inspection==0.4.2
#  + urllib3==2.6.3
#  + uuid-utils==0.14.0
#  + xxhash==3.6.0
#  + yarl==1.22.0
#  + zstandard==0.25.0

# %%
import os

from dotenv import load_dotenv

load_dotenv()


os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       3 from dotenv import load_dotenv
#       5 load_dotenv()
# ----> 8 os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
#
# File <frozen os>:690, in __setitem__(self, key, value)
#
# File <frozen os>:750, in check_str(value)
#
# TypeError: str expected, not NoneType

# %%
from langchain_community.document_loaders import TextLoader
